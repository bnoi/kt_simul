# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

import numpy as np

from kt_simul.io.parameters_io import ParamTree
from kt_simul.core.simul_spindle import Metaphase
from kt_simul.io.simuio import SimuIO
from kt_simul.core import parameters

PARAMFILE = parameters.PARAMFILE
MEASUREFILE = parameters.MEASUREFILE

# Change some parameters
paramtree = ParamTree(PARAMFILE)
paramtree.absolute_dic['dt'] = 10
paramtree.absolute_dic['span'] = 2000
paramtree.absolute_dic['t_A'] = 1750

measuretree = ParamTree(MEASUREFILE, adimentionalized=False)

# Init simu
meta = Metaphase(verbose=True, paramtree=paramtree, measuretree=measuretree, initial_plug='random')

# Launch simu
meta.simul()

# Save results
SimuIO(meta).save("simu.h5")

# Show trajectories (matplotlib needed)
meta.show()
# Out:
# 2025-02-05 14:56:01:INFO:kt_simul.core.simul_spindle: Parameters loaded
# 2025-02-05 14:56:01:INFO:kt_simul.core.simul_spindle: Simulation initialized
# 2025-02-05 14:56:01:INFO:kt_simul.core.simul_spindle: Running simulation
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2025-02-05 14:56:01:INFO:kt_simul.core.simul_spindle: Anaphase onset at 175 / 200
# 2025-02-05 14:56:01:INFO:kt_simul.core.simul_spindle: Simulation done
# 48% [=======================>                          ]
# 49% [=======================>                          ]
# 50% [========================>                         ]
# 51% [========================>                         ]
# 52% [=========================>                        ]
# 53% [=========================>                        ]
# 54% [==========================>                       ]
# 55% [==========================>                       ]
# ...

# %%
meta = SimuIO().read("simu.h5")
meta.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 meta = SimuIO().read("simu.h5")
# ----> 2 meta.show()
#
# File ~/Dev/Tyssue/kt_simul/kt_simul/core/simul_spindle.py:428, in Metaphase.show(self, ylim)
#     425 # Plot kymo
#     426 ax = plt.subplot(gs[len(kts)])
# --> 428 ax.plot(times, spbA, color="black", lw=2)
#     429 ax.plot(times, spbB, color="black", lw=2)
#     431 ax.axvline(anaphase, color="black")
#
# File ~/miniforge3/envs/quay/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
# ...
